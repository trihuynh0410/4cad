# %%
from utils import *

# %%
def shear(image_data):
	shearletSystem_norm = pyshearlab.SLgetShearletSystem2D(1,image_data.shape[0],image_data.shape[1],3)
	coeffs = pyshearlab.SLsheardec2D(image_data,shearletSystem_norm)
	# result = np.sum(np.abs(coeffs), axis=2)
	return coeffs

# %%
mri_data = nib.load("/mnt/data_lab513/tramy/4CAD/data/ADNI_out_mgz/CN/002_S_0559/mri/brain.finalsurfs.mgz").get_fdata()
aseg_data = nib.load("/mnt/data_lab513/tramy/4CAD/data/ADNI_out_mgz/CN/002_S_0559/mri/aseg.mgz").get_fdata()

# %%
ori, segment = process_hippo(mri_data, aseg_data)

# %%
import matplotlib.pyplot as plt

plt.imshow(ori, cmap='gray')
plt.show()

# %%
shearlet = shear(ori)
# Out:
# /home/tramy/miniconda3/envs/4cad/lib/python3.10/site-packages/pyshearlab/pyShearLab2D.py:157: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   h0, h1 = dfilters('dmaxflat4', 'd')/np.sqrt(2)
# /home/tramy/miniconda3/envs/4cad/lib/python3.10/site-packages/pyshearlab/pySLUtilities.py:40: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   h0, h1 = dfilters('dmaxflat4', 'd')/np.sqrt(2)
# ...

# %%
ori.shape
# Out:
# (256, 256)

# %%
shearlet.shape
# Out:
# (256, 256, 33)

# %%
import matplotlib.pyplot as plt

plt.imshow(shearlet[:,:,0], cmap='gray')
plt.show()
